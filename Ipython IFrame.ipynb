# %%
from IPython.display import IFrame,display
url = 'https://jupyterbook.org/advanced/html.html'
display(IFrame(url, width=1000, height=500))
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://jupyterbook.org/advanced/html.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='bD5le7k2uRU',width=900,height=500)
