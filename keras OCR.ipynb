# %%
# # https://medium.com/mlearning-ai/tesseract-vs-keras-ocr-vs-easyocr-ec8500b9455b
# !pip install keras_ocr
# !pip install tensorflow

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\aakas\.keras-ocr\craft_mlt_25k.h5
# ...
# Looking for C:\Users\aakas\.keras-ocr\crnn_kurapan.h5
# ...

# %%
images = [keras_ocr.tools.read(images) for images in['GST_Login_captcha.png','E://attitude.jpg']  ]

# %%
prediction_groups = pipeline.recognize(images)

# %%
# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)

# %%
# detector = keras_ocr.detection.Detector()
# recognizer = keras_ocr.recognition.Recognizer(weights='captcha')
