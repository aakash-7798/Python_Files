# %%
# !pip install PyPDF2
# Out:
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=706a7b7618cbd033336acbc17f7c7533791020c0dfb475b54d7a2464445622c6
#   Stored in directory: c:\users\aakas\appdata\local\pip\cache\wheels\d9\dc\ec\72da68331f30074b9950c1737c23cb8a67484e61498bc9713d
# Successfully built PyPDF2
# ...

# %%
import PyPDF2

# %%
Pdf_file = open("GSTR3B.pdf",'rb')

# %%
Pdf_Reader = PyPDF2.PdfFileReader(Pdf_file)

# %%
print(Pdf_Reader.numPages)
# Out:
# 2

# %%
print(Pdf_Reader.getPage(1).extractText())
