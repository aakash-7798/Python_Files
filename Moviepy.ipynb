# %%
# !pip install moviepy
# !pip install soundfile
# # https://towardsdatascience.com/extracting-speech-from-video-using-python-f0ec7e312d38
# # https://zulko.github.io/moviepy/getting_started/efficient_moviepy.html

# %%
from moviepy.editor import *

# %%
clip = VideoFileClip('E:\\www.7MovieRulz.sh - Akhanda (2021) 1080p Telugu TRUE WEB-DL - HEVC - UNTOUCHED - (DD+ 5.1 - 192Kbps & AAC 2.0) - 2.2GB - ESub.mkv')

# %%
def time_to_sec(t):
    h, m, s = map(int, t.split(':'))
    return h * 3600 + m * 60 + s

# %%
time_to_sec('00:8:55')
# Out:
# 535

# %%
# subclip = clip.subclip(time_to_sec('01:37:54'),time_to_sec('01:39:34'))
# subclip = clip.subclip(time_to_sec('02:13:35'),time_to_sec('02:14:12'))
# subclip = clip.subclip(time_to_sec('01:10:35'),time_to_sec('01:11:20'))
# subclip = clip.subclip(time_to_sec('01:42:04'),time_to_sec('01:42:56'))
# subclip = clip.subclip(time_to_sec('00:12:55'),time_to_sec('00:13:55'))
# subclip = clip.subclip(time_to_sec('01:39:00'),time_to_sec('01:39:32'))

# %%
# clip.ipython_display(t = time_to_sec('00:10:38'),hei)
# Out:
# <div align=middle><img  src='data:image/png;base64,...'></div>

# %%
# subclip.audio.write_audiofile(r"E:\Akhanda_Starting_Crop_Scene.wav")

# %%
# subclip.audio.write_audiofile(r"E:/Akhanda_Song_Om_Hara_Hara.wav")
# Out:
# MoviePy - Writing audio in E:/Akhanda_Song_Om_Hara_Hara.wav
# MoviePy - Done.

# %%
# subclip.write_videofile("E:\Akhanda_BGM_PoliceFight.mp4")

# %%
import speech_recognition as sr
# import soundfile as sf

# %%
r = sr.Recognizer()
# sf.read('E:\\Akhanda_Song_Om_Hara_Hara.mp3')

# %%
# audio = sr.AudioFile('E://Akhanda_Song_Om_Hara_Hara.wav')
audio = sr.AudioFile('E://Akhanda_Starting_Crop_Scene.wav')

# %%
with audio as source:
    audio_file = r.record(source)

# %%
# # https://cloud.google.com/speech-to-text/docs/languages
r.recognize_google(audio_file,language='te-IN',show_all=True)
# Out:
# {'alternative': [{'transcript': 'గుడి కొడకా', 'confidence': 0.47366679},
#   {'transcript': 'గుడి దగ్గర'},
#   {'transcript': 'పూరి కొడుకు'},
#   {'transcript': 'కొడకా'},
#   {'transcript': 'గుడి కొడుకు'}],
#  'final': True}
