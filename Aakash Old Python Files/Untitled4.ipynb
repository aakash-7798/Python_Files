# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(urlopen("http://www.avanthicollege.ac.in/"),"lxml")
soup1 = BeautifulSoup(urlopen("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html"))

# %%
urlopen("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html").read()
# Out:
# b'<html>\r\n  <head>\r\n   <TITLE>Osmania University bachelor degree 1st sem (CBCS) Ba Bcom Bsc BBA Results Dec 2016 Manabadi.com </TITLE>\r\n    <META NAME="Description" CONTENT=" \tOsmania University bachelor degree Ba Bcom Bsc supplementary Results 2015">\r\n    <META NAME="Keywords" CONTENT="ou degre supplementary results, ou degree results 2015,  bachelor degree, bachelor of commerce, ou results degree,  manabadi degree results.">\r\n    \t <script src="http://www.google-analytics.com/urchin.js" type="text/javascript"></script>\r\n\r\n\t\t <script>\r\n\t\t   (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\r\n\t\t   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\r\n\t\t   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\r\n\t\t   })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\r\n\r\n\t\t   ga(\'create\', \'UA-929033-1\', \'auto\');\r\n\t\t   ga(\'send\
# ...

# %%
soup1
# Out:
# <html>
# <head>
# <title>Osmania University bachelor degree 1st sem (CBCS) Ba Bcom Bsc BBA Results Dec 2016 Manabadi.com </title>
# <meta content=" 	Osmania University bachelor degree Ba Bcom Bsc supplementary Results 2015" name="Description"/>
# <meta content="ou degre supplementary results, ou degree results 2015,  bachelor degree, bachelor of commerce, ou results degree,  manabadi degree results." name="Keywords"/>
# <script src="http://www.google-analytics.com/urchin.js" type="text/javascript"></script>
# <script>
# 		   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 		   ga('create', 'UA-929033-1', 'auto');
# 		   ga('send', 'pageview');
#
# </script>
# <style type="text/css">
#       <!--
# ...

# %%
soup1.find_all("tr")
# Out:
# [<tr>
#  <td align="left" valign="middle" width="220">
#  <img src="images/logo3.jpg"/>
#  </td>
#  <td align="left" width="580">
#  <div align="center" style="width:400px;">
#  <img src="logo/Osmania-University.gif"/><br/>
#  <span style="color:#3300CC; font:bold 20px Verdana;">Osmania University</span>
#  </div>
#  </td>
#  </tr>,
#  <tr>
#  <td colspan="3" height="5"></td>
#  </tr>,
#  <tr>
#  <td align="left" valign="top">
#  <script type="text/javascript">
#  						    <!--
#  						    google_ad_client = "pub-2551325655874098";
#  						    google_ad_width = 160;
#  						    google_ad_height = 600;
#  						    google_ad_format = "160x600_as";
#  						    google_ad_type = "text_image";
#  						    //2007-10-01: manabadi.co.in
#  						    google_ad_channel = "6234839720";
#  						    google_color_border = "336699";
#  						    google_color_bg = "FFFFFF";
#  						    google_color_link = "0000FF";
#  						    google_color_text = "000000";
# ...

# %%
import mechanize

# %%
br = mechanize

# %%
import re
from mechanize import Browser

br = Browser("C:/Users/aakas/.wdm/drivers/chromedriver/win32/84.0.4147.30/chromedriver.exe")
br.open("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html")
br.select_form(name="resultsfrm")
# Browser passes through unknown attributes (including methods)
# to the selected HTMLForm (from ClientForm).
# br["cheeses"] = ["mozzarella", "caerphilly"]  # (the method here is __setitem__)
response = br.submit()  # submit current form
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e2ea8967084a> in <module>
#       8 # to the selected HTMLForm (from ClientForm).
#       9 # br["cheeses"] = ["mozzarella", "caerphilly"]  # (the method here is __setitem__)
# ---> 10 response = br.submit()  # submit current form
#
# ~\Anaconda\lib\site-packages\mechanize\_mechanize.py in submit(self, *args, **kwds)
#     695         Return value is same as for :meth:`open()`.
#     696         """
# --> 697         return self.open(self.click(*args, **kwds))
#     698
#     699     def click_link(self, link=None, **kwds):
#
# ~\Anaconda\lib\site-packages\mechanize\_mechanize.py in open(self, url_or_request, data, timeout)
#     255         :return: A :class:`mechanize.Response` object
#     256         '''
# --> 257         return self._mech_open(url_or_request, data, timeout=timeout)
#     258
# ...

# %%
br.select_table(name="resultsfrm").click(type = "button")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
 
#Getting local session of Chrome
driver=webdriver.Chrome("C:/Users/aakas/.wdm/drivers/chromedriver/win32/84.0.4147.30/chromedriver.exe")
 
#put here the adress of your page
driver.get("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html")
#put here the content you have put in Notepad, ie the XPath
elem = driver.find_elements_by_id("btnsubmit")
#elem2 = driver.find_elements_by_xpath("//*[@id='emailBounceBacks']/div/div[2]/label")
#("//*[@type='submit']")
#print(elem.get_attribute("class"))
#print(elem.get_attribute("value"))
elem.submit()

# %%
driver = webdriver.chrome('C:\\Users\\aakas\\Anaconda\\lib\\site-packages\\selenium\\webdriver\\chrome\\__init__.py')
driver.get("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html")
driver.execute_script("document.getElementById('btnsubmit').click()")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
 
#Getting local session of Chrome
# driver=webdriver.Chrome()
 
#put here the adress of your page
driver=webdriver.Chrome("C:/Users/aakas/.wdm/drivers/chromedriver/win32/84.0.4147.30/chromedriver.exe")
 
#put here the adress of your page
driver.get("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html")


button = driver.find_element_by_xpath("//button[@onclick=\"javascript:doSubmit('resultsfrm');\"]")
ActionChains(driver).move_to_element(button).click(button).perform()

# %%
from selenium.webdriver import ActionChains

# %%
ActionChains(browser).click(element).perform()

# %%
from selenium import webdriver

from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/84.0.4147.30/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\aakas\.wdm\drivers\chromedriver\win32\84.0.4147.30]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver=webdriver.Chrome("C:/Users/aakas/.wdm/drivers/chromedriver/win32/84.0.4147.30/chromedriver.exe")
driver.get("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html")
# inputElement = driver.find_element_by_xpath("//table/form[@name = 'resultsfrm']")
# driver.find_element_by_xpath("//iframe[@name='Dialogue Window']")
inputElement = driver.find_element_by_id()
inputElement.send_keys('105916467074')
inputElement.send_keys(Keys.ENTER)
# inputElement.submit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ad7377acb6aa> in <module>
#       5 driver.get("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html")
#       6 # inputElement = driver.find_element_by_xpath("//table/form[@name = 'resultsfrm']")
# ----> 7 inputElement = driver.find_element_by_id()
#       8 inputElement.send_keys('105916467074')
#       9 inputElement.send_keys(Keys.ENTER)
#
# TypeError: find_element_by_id() missing 1 required positional argument: 'id_'

# %%
from IPython.display import IFrame

# %%
IFrame("http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html",height=500,width=1000)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from selenium import webdriver
driver=webdriver.Chrome("C:/Users/aakas/.wdm/drivers/chromedriver/win32/84.0.4147.30/chromedriver.exe")
driver.get("http://stackoverflow.com/questions/7794087/running-javascript-in-selenium-using-python") 
driver.execute_script("document.getElementsByClassName('comment-user')[0].click()")
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# <ipython-input-19-779a34414eb5> in <module>
#       2 driver=webdriver.Chrome("C:/Users/aakas/.wdm/drivers/chromedriver/win32/84.0.4147.30/chromedriver.exe")
#       3 driver.get("http://stackoverflow.com/questions/7794087/running-javascript-in-selenium-using-python")
# ----> 4 driver.execute_script("document.getElementsByClassName('comment-user')[0].click()")
#
# ~\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--headless")

driver = webdriver.Chrome(
    executable_path='C:/Users/aakas/.wdm/drivers/chromedriver/win32/84.0.4147.30/chromedriver.exe',
    options=chrome_options)
driver.get('http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html')

firstnameField = driver.find_element_by_xpath("//table//form[@name='resultsfrm' and @id='resultsfrm']//tr[1]//input[@name='htno' and @id='105916467074']")
# lastnameField = driver.find_element_by_name('lastname')
# submitButton = driver.find_element_by_id('submit')

### METHOD 1 ###
# firstnameField.send_keys('105916467074')
# lastnameField.send_keys('Mitchell')
submitButton.click()
################

### METHOD 2 ###
#actions = ActionChains(driver).click(firstnameField).send_keys('Ryan').click(lastnameField).send_keys('Mitchell').send_keys(Keys.RETURN)
#actions.perform()
################

print(driver.find_element_by_tag_name('body').text)

driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-23-4588967921ce> in <module>
#      12 driver.get('http://www.results.manabadi.co.in/ou-degree-exam-regular-exam-results-2017.html')
#      13
# ---> 14 firstnameField = driver.find_element_by_xpath("//table//form[@name='resultsfrm' and @id='resultsfrm']//tr[1]//input[@name='htno' and @id='105916467074']")
#      15 # lastnameField = driver.find_element_by_name('lastname')
#      16 # submitButton = driver.find_element_by_id('submit')
#
# ~\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...
