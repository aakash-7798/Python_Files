# %%
### Data Import
import pandas as pd
CustomerData = pd.read_csv(r"D:\Files\MS-Office Files\CustomerData.csv")
print(CustomerData)
# Out:
#       CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0           1001     1             2              3              8     210
# 1           1002     1             2              3              6     442
# 2           1003     1             4              3              5     424
# 3           1004     1             1              6              6     261
# 4           1005     1             3              6              9     422
# ...          ...   ...           ...            ...            ...     ...
# 3204        4205     1             2              4              6     365
# 3205        4206     1             2              2              5     348
# 3206        4207     1             2              5              7     341
# 3207        4208     1             2              6              7     368
# 3208        4209     1             3              2              6     389
#
# ...

# %%
## Structure OF DataFrame
CustomerData.dtypes
CustomerData['City'] = CustomerData['City'].astype('category')
CustomerData.dtypes
# Out:
# CustomerID                         int64
# City                            category
# NoOfChildren                       int64
# MinAgeOfChild                      int64
# MaxAgeOfChild                      int64
# Tenure                             int64
# FrquncyOfPurchase                  int64
# NoOfUnitsPurchased                 int64
# FrequencyOFPlay                    int64
# NoOfGamesPlayed                    int64
# NoOfGamesBought                    int64
# FavoriteChannelOfTransaction      object
# FavoriteGame                      object
# TotalRevenueGenerated            float64
# dtype: object

# %%
print(CustomerData.head())
print(CustomerData.tail())
# Out:
#    CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0        1001     1             2              3              8     210
# 1        1002     1             2              3              6     442
# 2        1003     1             4              3              5     424
# 3        1004     1             1              6              6     261
# 4        1005     1             3              6              9     422
#
#    FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 0                 11                  11             2344              108
# 1                 20                  20              245               22
# 2                 18                  18             1059              130
# 3                 11                   9              365               34
# 4                 44                  31             1066              102
#
#    NoOfGamesBought FavoriteChannelOfTransaction FavoriteGame  \
# ...

# %%
print(CustomerData.describe())
# Out:
#         CustomerID         City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  \
# count  3209.000000  3209.000000   3209.000000    3209.000000    3209.000000
# mean   2605.000000     1.114054      2.128389       4.960735       7.990651
# std     926.502833     0.317927      1.035092       3.714191       8.784084
# min    1001.000000     1.000000      1.000000       0.000000       3.000000
# 25%    1803.000000     1.000000      1.000000       4.000000       6.000000
# 50%    2605.000000     1.000000      2.000000       5.000000       7.000000
# 75%    3407.000000     1.000000      3.000000       6.000000       8.000000
# max    4209.000000     2.000000     11.000000     113.000000     113.000000
#
#             Tenure  FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  \
# count  3209.000000        3209.000000         3209.000000      3209.000000
# mean    347.520411          16.269554           14.684014      1568.207853
# ...

# %%
CustomerData.info
# Out:
# <bound method DataFrame.info of       CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0           1001     1             2              3              8     210
# 1           1002     1             2              3              6     442
# 2           1003     1             4              3              5     424
# 3           1004     1             1              6              6     261
# 4           1005     1             3              6              9     422
# ...          ...   ...           ...            ...            ...     ...
# 3204        4205     1             2              4              6     365
# 3205        4206     1             2              2              5     348
# 3206        4207     1             2              5              7     341
# 3207        4208     1             2              6              7     368
# 3208        4209     1             3              2              6     389
#
# ...

# %%
### Accessing Column
CustomerData.loc[:,"TotalRevenueGenerated"]
# Out:
# 0       107.51
# 1       382.40
# 2       135.01
# 3       125.00
# 4       335.05
#          ...
# 3204    132.50
# 3205    223.23
# 3206    120.00
# 3207    161.50
# 3208    137.50
# Name: TotalRevenueGenerated, Length: 3209, dtype: float64

# %%
print(CustomerData.describe())
# Out:
#         CustomerID         City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  \
# count  3209.000000  3209.000000   3209.000000    3209.000000    3209.000000
# mean   2605.000000     1.114054      2.128389       4.960735       7.990651
# std     926.502833     0.317927      1.035092       3.714191       8.784084
# min    1001.000000     1.000000      1.000000       0.000000       3.000000
# 25%    1803.000000     1.000000      1.000000       4.000000       6.000000
# 50%    2605.000000     1.000000      2.000000       5.000000       7.000000
# 75%    3407.000000     1.000000      3.000000       6.000000       8.000000
# max    4209.000000     2.000000     11.000000     113.000000     113.000000
#
#             Tenure  FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  \
# count  3209.000000        3209.000000         3209.000000      3209.000000
# mean    347.520411          16.269554           14.684014      1568.207853
# ...

# %%
## Dropping Column 
CustomerData.drop("CustomerID",axis = 1)
# Out:
#       City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0        1             2              3              8     210
# 1        1             2              3              6     442
# 2        1             4              3              5     424
# 3        1             1              6              6     261
# 4        1             3              6              9     422
# ...    ...           ...            ...            ...     ...
# 3204     1             2              4              6     365
# 3205     1             2              2              5     348
# 3206     1             2              5              7     341
# 3207     1             2              6              7     368
# 3208     1             3              2              6     389
#
#       FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 0                    11                  11             2344              108
# ...

# %%
CustomerData.shape[1]
# Out:
# 14
