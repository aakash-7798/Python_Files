# %%
foo = "old_function"
bar = "new_function"

my_warning_message = (
    f"Warning, {foo} is deprecated, "
    "please use the new and way better "
    f"{bar}"
)

# %%
my_warning_message
# Out:
# 'Warning, old_function is deprecated, please use the new and way better new_function'

# %%
foo = "old_function"
bar = "new_function"

my_warning_message = (
    f"Warning, {foo} is deprecated, "
    f"please use the new and way better "
    f"{bar}"
)

# %%
my_warning_message
# Out:
# 'Warning, old_function is deprecated, please use the new and way better new_function'

# %%
value = str
f"Unknown recived value, got: {repr(value)}"
# Out:
# "Unknown recived value, got: <class 'str'>"

# %%
import pandas as pd
df = pd.DataFrame({
    "Name" : ["Aakash","Akshay"],
    "Profession" : ["Data Scientist","Chartered Accountant"],
    "Age" : [21,26]
}
            )
df
# Out:
#      Name            Profession  Age
# 0  Aakash        Data Scientist   21
# 1  Akshay  Chartered Accountant   26

# %%
df["Age"]
# Out:
# 0    21
# 1    26
# Name: Age, dtype: int64

# %%
df["Age"].max()
# Out:
# 26

# %%
df["Name"]
# Out:
# 0    Aakash
# 1    Akshay
# Name: Name, dtype: object

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   23.500000
# std     3.535534
# min    21.000000
# 25%    22.250000
# 50%    23.500000
# 75%    24.750000
# max    26.000000

# %%
sal = pd.read_csv('D:\\Files\\FolderFiles\\svmdeckdatasetcode\\adult_sal.csv')

# %%
sal
# Out:
#        Unnamed: 0  age     type_employer  fnlwgt   education  education_num  \
# 0               1   39         State-gov   77516   Bachelors             13
# 1               2   50  Self-emp-not-inc   83311   Bachelors             13
# 2               3   38           Private  215646     HS-grad              9
# 3               4   53           Private  234721        11th              7
# 4               5   28           Private  338409   Bachelors             13
# ...           ...  ...               ...     ...         ...            ...
# 32556       32557   27           Private  257302  Assoc-acdm             12
# 32557       32558   40           Private  154374     HS-grad              9
# 32558       32559   58           Private  151910     HS-grad              9
# 32559       32560   22           Private  201490     HS-grad              9
# 32560       32561   52      Self-emp-inc  287927     HS-grad              9
#
# ...

# %%
sal.head(10)
# Out:
#    Unnamed: 0  age     type_employer  fnlwgt  education  education_num  \
# 0           1   39         State-gov   77516  Bachelors             13
# 1           2   50  Self-emp-not-inc   83311  Bachelors             13
# 2           3   38           Private  215646    HS-grad              9
# 3           4   53           Private  234721       11th              7
# 4           5   28           Private  338409  Bachelors             13
# 5           6   37           Private  284582    Masters             14
# 6           7   49           Private  160187        9th              5
# 7           8   52  Self-emp-not-inc  209642    HS-grad              9
# 8           9   31           Private   45781    Masters             14
# 9          10   42           Private  159449  Bachelors             13
#
#                  marital         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
sal.dtypes
# Out:
# Unnamed: 0        int64
# age               int64
# type_employer    object
# fnlwgt            int64
# education        object
# education_num     int64
# marital          object
# occupation       object
# relationship     object
# race             object
# sex              object
# capital_gain      int64
# capital_loss      int64
# hr_per_week       int64
# country          object
# income           object
# dtype: object

# %%
sal.to_excel("D:\\Files\\sal.xlsx",sheet_name = "adult_sal",index = False)

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     32561 non-null  int64
#  1   age            32561 non-null  int64
#  2   type_employer  32561 non-null  object
#  3   fnlwgt         32561 non-null  int64
#  4   education      32561 non-null  object
#  5   education_num  32561 non-null  int64
#  6   marital        32561 non-null  object
#  7   occupation     32561 non-null  object
#  8   relationship   32561 non-null  object
#  9   race           32561 non-null  object
#  10  sex            32561 non-null  object
#  11  capital_gain   32561 non-null  int64
#  12  capital_loss   32561 non-null  int64
#  13  hr_per_week    32561 non-null  int64
#  14  country        32561 non-null  object
#  15  income         32561 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 4.0+ MB

# %%
age = sal["age"]
age.head()
# Out:
# 0    39
# 1    50
# 2    38
# 3    53
# 4    28
# Name: age, dtype: int64

# %%
type(sal["age"])
# Out:
# pandas.core.series.Series

# %%
sal["age"].shape
# Out:
# (32561,)

# %%
sal[["age","sex"]].head()
# Out:
#    age     sex
# 0   39    Male
# 1   50    Male
# 2   38    Male
# 3   53    Male
# 4   28  Female

# %%
type(sal[["age","sex"]])
# Out:
# pandas.core.frame.DataFrame

# %%
sal[["age","sex"]].shape
# Out:
# (32561, 2)

# %%
sal[sal["age"] > 35].head()
# Out:
#    Unnamed: 0  age     type_employer  fnlwgt  education  education_num  \
# 0           1   39         State-gov   77516  Bachelors             13
# 1           2   50  Self-emp-not-inc   83311  Bachelors             13
# 2           3   38           Private  215646    HS-grad              9
# 3           4   53           Private  234721       11th              7
# 5           6   37           Private  284582    Masters             14
#
#               marital         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 5  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital_gain  capital_loss  hr_per_week        country income
# ...

# %%
sal[sal["type_employer"] == "Private"]
# Out:
#        Unnamed: 0  age type_employer  fnlwgt     education  education_num  \
# 2               3   38       Private  215646       HS-grad              9
# 3               4   53       Private  234721          11th              7
# 4               5   28       Private  338409     Bachelors             13
# 5               6   37       Private  284582       Masters             14
# 6               7   49       Private  160187           9th              5
# ...           ...  ...           ...     ...           ...            ...
# 32555       32556   22       Private  310152  Some-college             10
# 32556       32557   27       Private  257302    Assoc-acdm             12
# 32557       32558   40       Private  154374       HS-grad              9
# 32558       32559   58       Private  151910       HS-grad              9
# 32559       32560   22       Private  201490       HS-grad              9
#
#                      marital         occupation   relationship   race     sex  \
# ...

# %%
sal[(sal["marital"] == "Divorced") | (sal["age"] > 35)]
# Out:
#        Unnamed: 0  age     type_employer  fnlwgt  education  education_num  \
# 0               1   39         State-gov   77516  Bachelors             13
# 1               2   50  Self-emp-not-inc   83311  Bachelors             13
# 2               3   38           Private  215646    HS-grad              9
# 3               4   53           Private  234721       11th              7
# 5               6   37           Private  284582    Masters             14
# ...           ...  ...               ...     ...        ...            ...
# 32552       32553   43           Private   84661  Assoc-voc             11
# 32554       32555   53           Private  321865    Masters             14
# 32557       32558   40           Private  154374    HS-grad              9
# 32558       32559   58           Private  151910    HS-grad              9
# 32560       32561   52      Self-emp-inc  287927    HS-grad              9
#
# ...

# %%
sal[sal["marital"].isin(["married","Divorced"])]
# Out:
#        Unnamed: 0  age     type_employer  fnlwgt     education  education_num  \
# 2               3   38           Private  215646       HS-grad              9
# 19             20   43  Self-emp-not-inc  292175       Masters             14
# 24             25   59           Private  109015       HS-grad              9
# 28             29   39           Private  367260       HS-grad              9
# 32             33   45           Private  386940     Bachelors             13
# ...           ...  ...               ...     ...           ...            ...
# 32538       32539   38           Private  139180     Bachelors             13
# 32543       32544   45         Local-gov  119199    Assoc-acdm             12
# 32544       32545   31           Private  199655       Masters             14
# 32546       32547   37           Private  198216    Assoc-acdm             12
# 32549       32550   43         State-gov  255835  Some-college             10
#
# ...

# %%
sal[sal["age"].notna()]
# Out:
#        Unnamed: 0  age     type_employer  fnlwgt   education  education_num  \
# 0               1   39         State-gov   77516   Bachelors             13
# 1               2   50  Self-emp-not-inc   83311   Bachelors             13
# 2               3   38           Private  215646     HS-grad              9
# 3               4   53           Private  234721        11th              7
# 4               5   28           Private  338409   Bachelors             13
# ...           ...  ...               ...     ...         ...            ...
# 32556       32557   27           Private  257302  Assoc-acdm             12
# 32557       32558   40           Private  154374     HS-grad              9
# 32558       32559   58           Private  151910     HS-grad              9
# 32559       32560   22           Private  201490     HS-grad              9
# 32560       32561   52      Self-emp-inc  287927     HS-grad              9
#
# ...

# %%
sal.loc[sal["marital"] == "Divorced","marital"].head()
# Out:
# 2     Divorced
# 19    Divorced
# 24    Divorced
# 28    Divorced
# 32    Divorced
# Name: marital, dtype: object

# %%
sal.iloc[1:10,7:15]
# Out:
#           occupation   relationship   race     sex  capital_gain  \
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
# 5    Exec-managerial           Wife  White  Female             0
# 6      Other-service  Not-in-family  Black  Female             0
# 7    Exec-managerial        Husband  White    Male             0
# 8     Prof-specialty  Not-in-family  White  Female         14084
# 9    Exec-managerial        Husband  White    Male          5178
#
#    capital_loss  hr_per_week        country
# 1             0           13  United-States
# 2             0           40  United-States
# 3             0           40  United-States
# 4             0           40           Cuba
# 5             0           40  United-States
# 6             0           16        Jamaica
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
kc = pd.read_excel("D:\\Files\\MS-Office Files\\KC_Country_Regression(2).xlsx")
kc.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long
# ...

# %%
kc.plot()

# %%
kc["sqft_living"].plot()

# %%
kc.plot.scatter(x ="sqft_living",y =  "price",alpha = 0.5)

# %%
kc.plot.box()

# %%
kc.iloc[:,1:5].plot.box()

# %%
kc.plot.area(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A4C683CAC8>,
# ...
#       dtype=object)

# %%
kc.iloc[:,1:5].plot.area(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A4C64A4D88>,
# ...
#       dtype=object)

# %%
fig , axs = plt.subplots(figsize = (12,4));
kc.plot.area(ax = axs)
