# %% [markdown]
# VISUALIZATION WITH ALL LIBRARIES

# %%
# #### Here I'm Reading the data From Drive
# ## It would Be easy for Reading 
# ### Below is the code for reading dataset from drive  
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
### Now I want to change the working Directory because it will be helpful for reading data
### Default pwd will be '/content'  but as i have mounted drive to colab 
### for Drive the default will be "/Drive/My Drive/colab Notebooks"
### If we just add "/content" to it will be easy for reading data

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/Project_Visualization(Python)'

# %% [markdown]
# PLEASE CHANGE PRESENT WORKING DIRECTORY
# GIVE WHERE YOU HAVE DOWNLOADED THE FILE

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Project_Visualization(Python)')

# %%
### Importing data set with the help of pandas Library
### Considering India_covid_Dataset
### Sir No need Worry about writing csv files Names
### When You type pd.read_csv() just enter the starting letter it will autocomplete
## Make sure for autocomplete dont type within inverted commas type the name and give inverted commas

# %%
import pandas as pd
Ag = pd.read_csv("AgeGroupDetails.csv")
Hb = pd.read_csv("HospitalBedsIndia.csv")
Ic = pd.read_csv("ICMRTestingLabs.csv")

# %%
Ag.head(10)
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 7    8    70-79          28      4.05%
# 8    9     >=80          10      1.45%
# 9   10  Missing           9      1.30%

# %%
Hb.head()
# Out:
#    Sno                   State/UT  ... NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 0    1  Andaman & Nicobar Islands  ...                       3                 500
# 1    2             Andhra Pradesh  ...                      65               16658
# 2    3          Arunachal Pradesh  ...                      10                 268
# 3    4                      Assam  ...                      50                6198
# 4    5                      Bihar  ...                     103                5936
#
# [5 rows x 12 columns]

# %%
Ic.head(10)
# Out:
#                                                  lab  ...                   type
# 0  ICMR-Regional Medical Research Centre, Port Blair  ...  Government Laboratory
# 1  Tomo Riba Institute of Health & Medical Scienc...  ...        Collection Site
# 2  Sri Venkateswara Institute of Medical Sciences...  ...  Government Laboratory
# 3                Rangaraya Medical College, Kakinada  ...  Government Laboratory
# 4               Sidhartha Medical College, Vijaywada  ...  Government Laboratory
# 5              Government Medical College, Anantapur  ...  Government Laboratory
# 6                     Guntur Medical College, Guntur  ...  Government Laboratory
# 7  Rajeev Gandhi Institute of Medical Sciences (R...  ...  Government Laboratory
# 8             Andhra Medical College, Vishakhapatnam  ...  Government Laboratory
# 9                  Gauhati Medical College, Guwahati  ...  Government Laboratory
#
# [10 rows x 6 columns]

# %%
Hb.dtypes
# Out:
# Sno                                   int64
# State/UT                             object
# NumPrimaryHealthCenters_HMIS         object
# NumCommunityHealthCenters_HMIS        int64
# NumSubDistrictHospitals_HMIS        float64
# NumDistrictHospitals_HMIS             int64
# TotalPublicHealthFacilities_HMIS      int64
# NumPublicBeds_HMIS                    int64
# NumRuralHospitals_NHP18               int64
# NumRuralBeds_NHP18                    int64
# NumUrbanHospitals_NHP18               int64
# NumUrbanBeds_NHP18                    int64
# dtype: object

# %%
Ic.dtypes
# Out:
# lab        object
# address    object
# pincode     int64
# city       object
# state      object
# type       object
# dtype: object

# %%
## After Datainspection We observed that in Ag dataframe Percentage column is

# %%
### info  is the function which tells about non_null values
Ag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sno         10 non-null     int64
#  1   AgeGroup    10 non-null     object
#  2   TotalCases  10 non-null     int64
#  3   Percentage  10 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 448.0+ bytes

# %%
Hb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Sno                               37 non-null     int64
#  1   State/UT                          37 non-null     object
#  2   NumPrimaryHealthCenters_HMIS      37 non-null     object
#  3   NumCommunityHealthCenters_HMIS    37 non-null     int64
#  4   NumSubDistrictHospitals_HMIS      30 non-null     float64
#  5   NumDistrictHospitals_HMIS         37 non-null     int64
#  6   TotalPublicHealthFacilities_HMIS  37 non-null     int64
#  7   NumPublicBeds_HMIS                37 non-null     int64
#  8   NumRuralHospitals_NHP18           37 non-null     int64
#  9   NumRuralBeds_NHP18                37 non-null     int64
#  10  NumUrbanHospitals_NHP18           37 non-null     int64
#  11  NumUrbanBeds_NHP18                37 non-null     int64
# ...

# %%
Ic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lab      267 non-null    object
#  1   address  267 non-null    object
#  2   pincode  267 non-null    int64
#  3   city     267 non-null    object
#  4   state    267 non-null    object
#  5   type     267 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 12.6+ KB

# %%
## If you want check only null or na values then following is code
Ag.isna().sum()
# Out:
# Sno           0
# AgeGroup      0
# TotalCases    0
# Percentage    0
# dtype: int64

# %%
### We observe that there are no na values for Ag

# %%
Hb.isna().sum()
# Out:
# Sno                                 0
# State/UT                            0
# NumPrimaryHealthCenters_HMIS        0
# NumCommunityHealthCenters_HMIS      0
# NumSubDistrictHospitals_HMIS        7
# NumDistrictHospitals_HMIS           0
# TotalPublicHealthFacilities_HMIS    0
# NumPublicBeds_HMIS                  0
# NumRuralHospitals_NHP18             0
# NumRuralBeds_NHP18                  0
# NumUrbanHospitals_NHP18             0
# NumUrbanBeds_NHP18                  0
# dtype: int64

# %%
## We observe that there are 7 na values for Hb dataset

# %%
Ic.isna().sum()
# Out:
# lab        0
# address    0
# pincode    0
# city       0
# state      0
# type       0
# dtype: int64

# %% [markdown]
# NOW WE VISUALLY SEE WHERE NA'S ARE PRESENT

# %% [markdown]
# I.MISSINGNO VISUALIZATION

# %%
import missingno as ms

# %%
ms.matrix(Ag)

# %% [markdown]
# FROM ABOVE PLOT WE CAN COME TO CONCLUSION THAT THERE ARE NO NA'S
# BECAUSE THERE ARE NO FLUCTUATIONS

# %%
ms.matrix(Hb)

# %% [markdown]
# FROM ABOVE PLOT WE CAN COME TO CONCLUSION THAT THERE ARE  NA'S
# BECAUSE WE CAN SEE SOME FLUCTUATIONS IN ONE COLUMN

# %%
ms.matrix(Ic)

# %% [markdown]
# FROM ABOVE PLOT WE CAN COME TO CONCLUSION THAT THERE ARE NO NA'S
# BECAUSE THERE ARE NO FLUCTUATIONS

# %% [markdown]
# WHAT IF WE WANT TO SEE THE MISSING VALUES OF THREE DATFRAMES SIDE BY SIDE THEN FOLLOWING CODE HELPS YOU

# %%
## We need Matplotlib for subplots
from matplotlib import pyplot as plt
fig,(ax1,ax2,ax3) = plt.subplots(1,3)
fig.set_size_inches(30,5)
ms.matrix(Ag,ax = ax1)
ms.matrix(Hb,ax = ax2)
ms.matrix(Ic,ax = ax3) 
ax1.set_title("AgeGroup_Dataframe_Plot",fontdict={'fontsize' : 25})
ax3.set_title("ICMR_Dataframe_Plot",fontdict={'fontsize' : 25})
ax2.set_title("Hospitalbedroom_Dataframe_Plot",fontdict={'fontsize' : 25},loc="center")
# Out:
# /usr/local/lib/python3.6/dist-packages/missingno/missingno.py:61: UserWarning:
#
# Plotting a sparkline on an existing axis is not currently supported. To remove this warning, set sparkline=False.
# Text(0.5, 1.0, 'Hospitalbedroom_Dataframe_Plot')

# %% [markdown]
# SEE FROM ABOVE PLOTS WE CAN EASILY IDENTIFY WHICH DATAFRAMES AS NA'S

# %% [markdown]
# SIMILARLY WE CAN SEE DIFFERENT PLOTS IN MISSINGNO

# %%
## We need Matplotlib for subplots
from matplotlib import pyplot as plt
# plt.rcParams["axes.grid"] = False
# plt.rcParams['axes.facecolor'] = 'none'
fig,(ax1,ax2,ax3) = plt.subplots(1,3)
fig.set_size_inches(25,5)
ms.bar(Ag,color = "blue",ax = ax1)
ms.bar(Hb,color = "red",ax = ax2)
ms.bar(Ic,color = "green",ax = ax3) 
ax1.set_title("AgeGroup_Dataframe_Plot",fontdict={'fontsize' : 25})
ax3.set_title("ICMR_Dataframe_Plot",fontdict={'fontsize' : 25})
ax2.set_title("Hospitalbedroom_Dataframe_Plot",fontdict={'fontsize' : 25})
# Out:
# Text(0.5, 1.0, 'Hospitalbedroom_Dataframe_Plot')

# %% [markdown]
# FROM ABOVE PLOTS WE SEE THAT TO THE TOP OF EACH BAR REPRESENTS TOTAL DATAPOINTS   AND
# TO THE RIGHT OF EACH PLOT REPRESENTS NO.OF DATAPOINTS PRESENT IN DATAFRAME
#
# WE OBSERVE THAT IN Hospitalbedroom_Dataframe_Plot THERE ARE NA'S

# %% [markdown]
# ANOTHER APPROACH FOR ABOVE PLOTTING

# %%
## We need Matplotlib for subplots
from matplotlib import pyplot as plt
fig,(ax1,ax2,ax3) = plt.subplots(3,1)
fig.set_size_inches(10,20)
ms.bar(Ag,color = "blue",ax = ax1)
ms.bar(Hb,color = "red",ax = ax2)
ms.bar(Ic,color = "green",ax = ax3) 
ax1.set_title("AgeGroup_Dataframe_Plot",fontdict={'fontsize' : 25})
ax3.set_title("ICMR_Dataframe_Plot",fontdict={'fontsize' : 25})
ax2.set_title("Hospitalbedroom_Dataframe_Plot",fontdict={'fontsize' : 25})
# Out:
# Text(0.5, 1.0, 'Hospitalbedroom_Dataframe_Plot')

# %% [markdown]
# II.SEABORN VISUALIZATION

# %% [markdown]
# BEFORE APPLYING VISUALIZATION I JUST WANT TO FILLNA  WITH MEDIAN

# %%
import numpy as np
# np.median(Hb.NumSubDistrictHospitals_HMIS) # This gives Nan as result
# np.isnan(Hb.NumSubDistrictHospitals_HMIS)  #This gives whether Nan is present
# Hb.NumSubDistrictHospitals_HMIS[~np.isnan(Hb.NumSubDistrictHospitals_HMIS)]  # This gives the values with no Nan's 
np.median(Hb.NumSubDistrictHospitals_HMIS[~np.isnan(Hb.NumSubDistrictHospitals_HMIS)])  ## This gives the median without Nan
# Out:
# 25.5

# %%
## Now I will fill Nan's with median value 25.5
Hb.fillna(25.5,inplace=True)
Hb
# Out:
#     Sno                   State/UT  ... NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 0     1  Andaman & Nicobar Islands  ...                       3                 500
# 1     2             Andhra Pradesh  ...                      65               16658
# 2     3          Arunachal Pradesh  ...                      10                 268
# 3     4                      Assam  ...                      50                6198
# 4     5                      Bihar  ...                     103                5936
# 5     6                 Chandigarh  ...                       4                 778
# 6     7               Chhattisgarh  ...                      45                4342
# 7     8       Dadra & Nagar Haveli  ...                       1                 316
# 8     9                Daman & Diu  ...                       0                   0
# 9    10                      Delhi  ...                     109               24383
# ...

# %% [markdown]
# TYPES OF PLOTS
#
#
# 1.   BOX PLOT:
#
#   *A box and whisker plot is a way of summarizing a set of data measured on an interval scale. It is often used in explanatory data analysis.
#
#   *This type of graph is used to show the shape of the distribution, its central value, and its variability
#
# 2.   VIOLIN PLOT:
#
#  * A violin plot is a method of plotting numeric data. It is similar to a box plot, with the addition of a rotated kernel density plot on each side.
#
#  *While a box plot only shows summary statistics such as mean/median and interquartile ranges, the violin plot shows the full distribution of the data.
#
#
# 3.   SCATTER PLOT:
#
#  *Scatter plots are used to plot data points on a horizontal and a vertical axis in the attempt to show how much one variable is affected by another.
#
#  *Each row in the data table is represented by a marker whose position depends on its values in the columns set on the X and Y axes.
#
#
# 4.   BAR PLOT:
#
#  * It shows the relationship between a numeric and categoric variable
#  *  Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.
#
# 5.   HISTOGRAM:
#
#  *histogram is used to plot the frequency of score occurrences in a continuous data set that has been divided into classes, called bins
#
#
# 6.   SWARM PLOT :
#  * The swarm plot (a plotting style also referred to as a “beeswarm)    really shines when used to display continuous data juxtaposed with a categorical metric.
#
# 7.   DIST PLOT :
#  * It is used to visualize the parametric distribution of a dataset.

# %%
import seaborn as sns

# %% [markdown]
# 1.BOX_PLOT(TIPS DATASET)

# %%
tips = pd.read_csv("tips.csv")

# %%
tips.head(10)
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4
# 5           5       25.29  4.71    Male     No  Sun  Dinner     4
# 6           6        8.77  2.00    Male     No  Sun  Dinner     2
# 7           7       26.88  3.12    Male     No  Sun  Dinner     4
# 8           8       15.04  1.96    Male     No  Sun  Dinner     2
# 9           9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
 tips.drop(columns=["Unnamed: 0"],inplace=True,axis = 1)
 tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
### Taking x-axes as object variable and y_axis as numerical will give you good boxplot
sns.boxplot(x="day",y = "total_bill",data = tips)

# %%
## Hue Aesthitic divides the boxplots into categories
sns.boxplot(x="day",y = "total_bill",data = tips,hue="smoker")

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# HOW LONG WILL WE CONTINUOUSLY SEE ALL KINDS OF DATPOINTS INDIVIDUALLY
#
# I JUST WANT TO SEE THE  BOXPLOTS OF WHOLE DATAPOINTS IN SINGLE FRAME
#
# THE FOLLOWING CODE WILL BE HELPFUL

# %%
### COSIDERING NUMERICAL COLUMNS AND CATEGORICAL COLUMNS INTO DIFFERENT LISTS
from matplotlib import pyplot as plt
tips_num = ['total_bill', 'tip','size']
tips_obj = [ 'sex','smoker','day','time']
### MAKING SUBPLOTS 
fig,axes = plt.subplots(4,3)
fig.set_size_inches(20,17)
plt.rcParams["axes.labelsize"] = 15 
for i in range(len(tips_obj)):
  for j in range(len(tips_num)):
           sns.boxplot(x = tips_obj[i],y = tips_num[j],data = tips,ax = axes[i,j])

# %% [markdown]
# BELOW CODES ARE ADDING SOME AESTHITICS TO ABOVE CODE
# IF WANT TO CHECK THEM
# JUST UNCOMMENT IT
# (FIRST CTRL+A  AND THEN  CTRL+/ )

# %%
# #### Adding Aesthitic hue
# ### Below is code for random selection of hue
# fig,axes = plt.subplots(4,3)
# fig.set_size_inches(20,17)
# plt.rcParams["axes.labelsize"] = 15
# for i in range(len(tips_obj)):
#   for j in range(len(tips_num)):
#            sns.boxplot(x = tips_obj[i],y = tips_num[j],hue = tips_obj[j],data = tips,ax = axes[i,j])

# %%
# #### Adding Aesthitic hue
# ### Below is code for sex with all categorical variable
# fig,axes = plt.subplots(3,4)
# fig.set_size_inches(20,17)
# plt.rcParams["axes.labelsize"] = 15
# for i in range(len(tips_obj)):
#   for j in range(len(tips_num)):
#            sns.boxplot(x = tips_obj[0],y = tips_num[j],hue = tips_obj[i],data = tips,ax = axes[j,i])

# %%
# #### Adding Aesthitic hue
# ### Below is code for smoker with all categorical variable
# fig,axes = plt.subplots(3,4)
# fig.set_size_inches(20,17)
# plt.rcParams["axes.labelsize"] = 15
# for i in range(len(tips_obj)):
#   for j in range(len(tips_num)):
#            sns.boxplot(x = tips_obj[1],y = tips_num[j],hue = tips_obj[i],data = tips,ax = axes[j,i])

# %%
# #### Adding Aesthitic hue
# ### Below is code for day with all categorical variable
# fig,axes = plt.subplots(3,4)
# fig.set_size_inches(20,17)
# plt.rcParams["axes.labelsize"] = 15
# for i in range(len(tips_obj)):
#   for j in range(len(tips_num)):
#            sns.boxplot(x = tips_obj[2],y = tips_num[j],hue = tips_obj[i],data = tips,ax = axes[j,i])

# %% [markdown]
# SIMILARLY WE CAN APPLY THE SAME CODE FOR ALL PLOTS

# %% [markdown]
# 2.VIOLIN PLOT(TIPS DATASET)

# %%
fig,axes = plt.subplots(4,3)
fig.set_size_inches(20,17)
plt.rcParams["axes.labelsize"] = 15
for i in range(len(tips_obj)):
  for j in range(len(tips_num)):
           sns.violinplot(x = tips_obj[i],y = tips_num[j],hue = tips_obj[i],data = tips,ax = axes[i,j],palette= "Set1")

# %% [markdown]
# 3.SCATTERPLOT(Hb DATASET)

# %%
Hb1 = Hb.iloc[0:36,:]

# %%
Hb1.tail(10)
# Out:
#     Sno       State/UT  ... NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 26   27     Puducherry  ...                      11                3473
# 27   28         Punjab  ...                     172               12128
# 28   29      Rajasthan  ...                     150               10760
# 29   30         Sikkim  ...                       9                1300
# 30   31     Tamil Nadu  ...                     525               37353
# 31   32      Telangana  ...                      61               13315
# 32   33        Tripura  ...                      56                3277
# 33   34  Uttar Pradesh  ...                     193               37156
# 34   35    Uttarakhand  ...                      50                5228
# 35   36    West Bengal  ...                     294               58882
#
# [10 rows x 12 columns]

# %%
Hb2 = Hb1.select_dtypes(exclude="object")

# %%
Hb2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Sno                               36 non-null     int64
#  1   NumCommunityHealthCenters_HMIS    36 non-null     int64
#  2   NumSubDistrictHospitals_HMIS      36 non-null     float64
#  3   NumDistrictHospitals_HMIS         36 non-null     int64
#  4   TotalPublicHealthFacilities_HMIS  36 non-null     int64
#  5   NumPublicBeds_HMIS                36 non-null     int64
#  6   NumRuralHospitals_NHP18           36 non-null     int64
#  7   NumRuralBeds_NHP18                36 non-null     int64
#  8   NumUrbanHospitals_NHP18           36 non-null     int64
#  9   NumUrbanBeds_NHP18                36 non-null     int64
# dtypes: float64(1), int64(9)
# memory usage: 2.9 KB

# %%
Hb2.columns
# Out:
# Index(['Sno', 'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18'],
#       dtype='object')

# %%
sns.scatterplot(x = "TotalPublicHealthFacilities_HMIS",y = "NumPublicBeds_HMIS",data = Hb2)

# %% [markdown]
# WE WILL SEE ALL KINDS OF SCATTERPLOTS

# %%
Hb2.columns
# Out:
# Index(['Sno', 'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18'],
#       dtype='object')

# %% [markdown]
# To View the below code just uncomment it(First ctrl+a  then ctrl+/)

# %%
# Hb2_c1 = ['NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS','NumPublicBeds_HMIS']       
# Hb2_c2 = [ 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18']
# fig,axes = plt.subplots(5,4)
# fig.set_size_inches(26,26)
# plt.rcParams["axes.labelsize"] = 15
# for i in range(len(Hb2_c1)):
#   for j in range(len(Hb2_c2)):
#            sns.scatterplot(x = Hb2_c1[i],y = Hb2_c2[j],data = Hb1,ax = axes[i,j])

# %%
#### APPLYING DIFFERENT COLORS
Hb2_c1 = ['NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
       'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS','NumPublicBeds_HMIS']       
Hb2_c2 = [ 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
       'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18']
col_s  = ['blue','red','green','black']   
fig,axes = plt.subplots(5,4)
fig.set_size_inches(26,26)
plt.rcParams["axes.labelsize"] = 15
plt.legend(bbox_to_anchor=(1, 1), loc=7, borderaxespad=0.)
for i in range(len(Hb2_c1)):
  for j in range(len(Hb2_c2)):
           sns.scatterplot(x = Hb2_c1[i],y = Hb2_c2[j],data = Hb1,ax = axes[i,j],size = (np.random.rand(36)*1000000),color = col_s[j])
# Out:
# No handles with labels found to put in legend.

# %%
# #### APPLYING DIFFERENT COLORS
# ###  MAKING ROWS AS COLUMNS
# Hb2_c1 = ['NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS','NumPublicBeds_HMIS']       
# Hb2_c2 = [ 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18']
# col_s  = ['blue','red','green','black',"yellow"]   
# fig,axes = plt.subplots(4,5)
# fig.set_size_inches(28,26)
# plt.rcParams["axes.labelsize"] = 15
# plt.legend(bbox_to_anchor=(1, 1), loc=7, borderaxespad=0.)
# for i in range(len(Hb2_c1)):
#   for j in range(len(Hb2_c2)):
#            sns.scatterplot(x = Hb2_c2[j],y = Hb2_c1[i],data = Hb1,ax = axes[j,i],size = (np.random.rand(36)*1000000),color = col_s[i])

# %% [markdown]
# III.MATPLOTLIB VISUALIZATION

# %% [markdown]
# HISTOGRAM

# %%
from matplotlib import pyplot as plt

# %%
### CONSIDERING IRIS DATASET
iris = pd.read_csv("Iris.csv")
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.hist(iris.SepalWidthCm)
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <a list of 10 Patch objects>)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
fig,axes = plt.subplots(2,2)
fig.set_size_inches(20,10)
axes[0,0].hist(iris.iloc[:,1],color = "red")
axes[0,1].hist(iris.iloc[:,2])        
axes[1,0].hist(iris.iloc[:,3],color = "green")
axes[1,1].hist(iris.iloc[:,4],color = "black")
axes[0,0].set_xlabel("SepalLengthCm")
axes[0,1].set_xlabel("SepalWidththCm")
axes[1,0].set_xlabel("PetalLengthCm")
axes[1,1].set_xlabel("PetalWidththCm")
# Out:
# Text(0.5, 0, 'PetalWidththCm')

# %%
iris.iloc[:,1]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
# fig,axes = plt.subplots(2,2)
# fig.set_size_inches(20,10)
# for i in range(2):
#   for j in range(2):
#     for k in range(1,5):
#       axes[i,j].hist(iris.iloc[:,k])

# %% [markdown]
# BARGRAPH

# %%
# fig,axes = plt.subplots(2,2)
# fig.set_size_inches(20,10)
# axes[0,0].bar(iris.iloc[:,1],height = iris.iloc[:,4],color = "red")
# axes[0,1].bar(iris.iloc[:,2],height = iris.iloc[:,3])        
# axes[1,0].bar(iris.iloc[:,3],height = iris.iloc[:,2],color = "green")
# axes[1,1].bar(iris.iloc[:,4],height = iris.iloc[:,1],color = "black")
# axes[0,0].set_xlabel("SepalLengthCm")
# axes[0,1].set_xlabel("SepalWidththCm")
# axes[1,0].set_xlabel("PetalLengthCm")
# axes[1,1].set_xlabel("PetalWidththCm")

# %% [markdown]
# LINE GRAPH

# %%
stocks = pd.read_excel("stocks_sample.xlsx")

# %%
stocks.head(10)
# Out:
#         date   open   high    low  close    volume
# 0 2013-02-08  15.07  15.12  14.63  14.75   8407500
# 1 2013-02-11  14.89  15.01  14.26  14.46   8882000
# 2 2013-02-12  14.45  14.51  14.10  14.27   8126000
# 3 2013-02-13  14.30  14.94  14.25  14.66  10259500
# 4 2013-02-14  14.94  14.96  13.16  13.99  31879900
# 5 2013-02-15  13.93  14.61  13.93  14.50  15628000
# 6 2013-02-19  14.33  14.56  14.08  14.26  11354400
# 7 2013-02-20  14.17  14.26  13.15  13.33  14725200
# 8 2013-02-21  13.62  13.95  12.90  13.37  11922100
# 9 2013-02-22  13.57  13.60  13.21  13.57   6071400

# %%
plt.plot(stocks.date,stocks.open)

# %%
fig,ax = plt.subplots(2,2)
fig.set_size_inches(20,10)
ax[0,0].plot(stocks.date,stocks.open,linestyle = '--',marker = '*',linewidth = '3',markersize = '5',color = 'red')
ax[0,1].plot(stocks.date,stocks.close,linestyle = '--',marker = '*',linewidth = '3',markersize = '5',color = 'blue')
ax[1,0].plot(stocks.date,stocks.high,linestyle = '--',marker = '*',linewidth = '3',markersize = '5',color = 'black')
ax[1,1].plot(stocks.date,stocks.low,linestyle = '--',marker = '*',linewidth = '3',markersize = '5',color = 'green')
ax[0,0].set_xlabel("STOCKS_DATE")
ax[0,1].set_xlabel("STOCKS_DATE")
ax[1,0].set_xlabel("STOCKS_DATE")
ax[1,1].set_xlabel("STOCKS_DATE")
ax[0,0].set_ylabel("STOCKS_OPEN")
ax[0,1].set_ylabel("STOCKS_CLOSE")
ax[1,0].set_ylabel("STOCKS_HIGH")
ax[1,1].set_ylabel("STOCKS_LOW")
# Out:
# Text(0, 0.5, 'STOCKS_LOW')

# %%
plt.figure(figsize=(20,10))
plt.title("ALL STOCKS FROM OPEN TO CLOSE")
plt.plot(stocks.date,stocks.open)
plt.plot(stocks.date,stocks.close)
plt.plot(stocks.date,stocks.high)
plt.plot(stocks.date,stocks.low)
plt.legend(['OPEN','CLOSE','HIGH','LOW'],prop={'size': 15})

# %% [markdown]
# IV.PLOTLY VISUALIZATION

# %%
### LET US SEE HOW THE ABOVE LINE GRAPH APPEARS IN PLOTLY WITH SAME DATASET
import plotly.express as px
px.line(stocks,x = "date",y = "open")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e56fe8e9-bd1f-46f1-a5a9-64b029222e71" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e56fe8e9-bd1f-46f1-a5a9-64b029222e71")) {
#                     Plotly.newPlot(
#                         'e56fe8e9-bd1f-46f1-a5a9-64b029222e71',
# ...

# %%
stocks.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume'], dtype='object')

# %% [markdown]
# IF WE OBSERVE THE LINE CHAT IN MATPLOTLIB AND THE SCATTER(I.E LINE) IN PYPLOT
#
# PYPLOT SCATTER PLOT IS VISUALLY WONDERFUL AND DATA IS EASILY UNDERSTANDABLE

# %%
#### SUBPLOTS  IN PYPLOT
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = make_subplots(rows = 3,cols = 2,subplot_titles=("STOCKS_OPEN", "STOCKS_CLOSE", "STOCKS_HIGH", "STOCKS_LOW"))
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.open,name ="Open" ),row=1, col=1)
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.close,name ="Close" ),row=1, col=2)
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.high,name = "High" ),row=2, col=1)
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.low,name = "Low"),row=2, col=2)
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.volume,name = "Volume"),row=3, col=1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5db1526d-d112-43c0-a393-8e5e8cd38f23" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5db1526d-d112-43c0-a393-8e5e8cd38f23")) {
#                     Plotly.newPlot(
#                         '5db1526d-d112-43c0-a393-8e5e8cd38f23',
# ...

# %%
## IF WE WANT TWO DIFFERENT DATA IN SINGLE CHART THEN FOLLOWING IS USEFUL CODE
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.open,name = "open"))
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.close,name = "close"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ee0dfd53-a60a-4176-a0e5-41717550bc10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee0dfd53-a60a-4176-a0e5-41717550bc10")) {
#                     Plotly.newPlot(
#                         'ee0dfd53-a60a-4176-a0e5-41717550bc10',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.open,name = "high"))
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.close,name = "low"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a063e321-f469-489e-b8e5-d24400cebe92" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a063e321-f469-489e-b8e5-d24400cebe92")) {
#                     Plotly.newPlot(
#                         'a063e321-f469-489e-b8e5-d24400cebe92',
# ...

# %%
## IF WE WANT TWO DIFFERENT DATA IN SINGLE CHART THEN FOLLOWING IS USEFUL CODE
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.open,name ="Open"))
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.close,name ="Close"))
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.high,name = "High"))
fig.add_trace(go.Scatter(x = stocks.date,y = stocks.low,name = "Low"))
# fig.add_trace(go.Scatter(x = stocks.date,y = stocks.volume,name = "Volume"),row=1, col=1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="601d1624-00ae-41eb-b270-b2e603504f33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("601d1624-00ae-41eb-b270-b2e603504f33")) {
#                     Plotly.newPlot(
#                         '601d1624-00ae-41eb-b270-b2e603504f33',
# ...

# %%
# #### SUBPLOTS  IN PYPLOT
# import plotly.express as px
# import plotly.graph_objects as go
# from plotly.subplots import make_subplots
# st_col = ['open', 'high', 'low', 'close', 'volume']
# fig = make_subplots(rows = 1,cols = 5,subplot_titles=("STOCKS_OPEN", "STOCKS_CLOSE", "STOCKS_HIGH", "STOCKS_LOW","STOCKS_VOLUME"))
# # r = [1,2,3]
# # c = [1,2]
# for i in range(len(st_col)):
#   for j in range(1,6):
# #     for k in range(len(c)):
#       fig.add_trace(go.Scatter(x = stocks.date,y = stocks[st_col[i]],name = st_col[i]),row=1, col=j)



#     # row=(j // 2) + 1, col=((j % 2) + 1  )

# %%
# fig.update_layout(showlegend = False)
# fig.show()
# stocks.date

# %%
Hb1.head(5)
# Out:
#    Sno                   State/UT  ... NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 0    1  Andaman & Nicobar Islands  ...                       3                 500
# 1    2             Andhra Pradesh  ...                      65               16658
# 2    3          Arunachal Pradesh  ...                      10                 268
# 3    4                      Assam  ...                      50                6198
# 4    5                      Bihar  ...                     103                5936
#
# [5 rows x 12 columns]

# %%
import plotly.express as px
px.bar(Hb1, x ="State/UT",y ="NumDistrictHospitals_HMIS")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="67e384c3-cbe5-4ebf-b95e-ce844adc9935" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67e384c3-cbe5-4ebf-b95e-ce844adc9935")) {
#                     Plotly.newPlot(
#                         '67e384c3-cbe5-4ebf-b95e-ce844adc9935',
# ...

# %%
px.pie(Hb1,names ="State/UT",values = "NumCommunityHealthCenters_HMIS")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b9eeccee-6d38-4bb7-9c95-cc45ec6074b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b9eeccee-6d38-4bb7-9c95-cc45ec6074b4")) {
#                     Plotly.newPlot(
#                         'b9eeccee-6d38-4bb7-9c95-cc45ec6074b4',
# ...

# %%
Ic.head(5)
# Out:
#                                                  lab  ...                   type
# 0  ICMR-Regional Medical Research Centre, Port Blair  ...  Government Laboratory
# 1  Tomo Riba Institute of Health & Medical Scienc...  ...        Collection Site
# 2  Sri Venkateswara Institute of Medical Sciences...  ...  Government Laboratory
# 3                Rangaraya Medical College, Kakinada  ...  Government Laboratory
# 4               Sidhartha Medical College, Vijaywada  ...  Government Laboratory
#
# [5 rows x 6 columns]

# %%
px.bar(Ic,x = "state", y= "city")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eecc54c8-3df7-45b1-ae48-22eec4663c5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eecc54c8-3df7-45b1-ae48-22eec4663c5a")) {
#                     Plotly.newPlot(
#                         'eecc54c8-3df7-45b1-ae48-22eec4663c5a',
# ...

# %%
px.bar(Ic,x = "state", y= "pincode",color = "city")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c939c195-3347-42e9-b0ea-961690abd9af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c939c195-3347-42e9-b0ea-961690abd9af")) {
#                     Plotly.newPlot(
#                         'c939c195-3347-42e9-b0ea-961690abd9af',
# ...

# %%
px.bar(Ic,x = "state", y= "pincode",color = "type")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="12b7cfb9-7a40-42a5-90cf-8f2e2f3c1cf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("12b7cfb9-7a40-42a5-90cf-8f2e2f3c1cf0")) {
#                     Plotly.newPlot(
#                         '12b7cfb9-7a40-42a5-90cf-8f2e2f3c1cf0',
# ...

# %%
px.bar(Ic,x = "state", y= "pincode",color = "city",facet_col="type")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b79f65c-d90e-43d1-b10b-c14664d8a76a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b79f65c-d90e-43d1-b10b-c14664d8a76a")) {
#                     Plotly.newPlot(
#                         '1b79f65c-d90e-43d1-b10b-c14664d8a76a',
# ...

# %%
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# #### SUBPLOTS  IN PYPLOT
# import plotly.express as px
# import plotly.graph_objects as go
# from plotly.subplots import make_subplots
# fig = make_subplots(rows = 2,cols = 2)
# r = [1,2]
# c = [1,2]
# for i in range(1,5):
#   for j in range(len(r)):
#     for k in range(len(c)):
#       fig.add_trace(go.Box(x = iris.Species,y = iris.iloc[:,i],name = iris.columns[i]),row=r[j], col=c[k])



#     # row=(j // 2) + 1, col=((j % 2) + 1  )

# %%
# fig.show()

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = make_subplots(rows = 2,cols = 2)
fig.add_trace(go.Box(x = iris.Species,y = iris.iloc[:,1],name = iris.columns[1]),row=1, col=1)
fig.add_trace(go.Box(x = iris.Species,y = iris.iloc[:,2],name = iris.columns[2]),row=1, col=2)
fig.add_trace(go.Box(x = iris.Species,y = iris.iloc[:,3],name = iris.columns[3]),row=2, col=1)
fig.add_trace(go.Box(x = iris.Species,y = iris.iloc[:,4],name = iris.columns[4]),row=2, col=2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1a7605b9-3f50-4fae-92e0-7267ffc8c24f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1a7605b9-3f50-4fae-92e0-7267ffc8c24f")) {
#                     Plotly.newPlot(
#                         '1a7605b9-3f50-4fae-92e0-7267ffc8c24f',
# ...

# %%
Ag.head(10)
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 7    8    70-79          28      4.05%
# 8    9     >=80          10      1.45%
# 9   10  Missing           9      1.30%

# %%
px.scatter(Ag,x = "AgeGroup",y = "TotalCases",size = "TotalCases" )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="12badf7e-657a-4856-a2e8-f810ab2b3dbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("12badf7e-657a-4856-a2e8-f810ab2b3dbc")) {
#                     Plotly.newPlot(
#                         '12badf7e-657a-4856-a2e8-f810ab2b3dbc',
# ...

# %%
Hb1.head(5)
# Out:
#    Sno                   State/UT  ... NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 0    1  Andaman & Nicobar Islands  ...                       3                 500
# 1    2             Andhra Pradesh  ...                      65               16658
# 2    3          Arunachal Pradesh  ...                      10                 268
# 3    4                      Assam  ...                      50                6198
# 4    5                      Bihar  ...                     103                5936
#
# [5 rows x 12 columns]

# %%
px.scatter(Hb1, x = Hb1.iloc[:,3],y =Hb1.iloc[:,4],size = Hb1.iloc[:,4])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="41895655-d20f-426b-95e5-54b58f2b8569" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41895655-d20f-426b-95e5-54b58f2b8569")) {
#                     Plotly.newPlot(
#                         '41895655-d20f-426b-95e5-54b58f2b8569',
# ...

# %%
px.scatter_3d(Hb1, x = Hb1.iloc[:,3],y =Hb1.iloc[:,4],z =Hb1.iloc[:,5] ,size = Hb1.iloc[:,4],color = Hb1.iloc[:,1])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5253dca1-1cc7-4d0a-9149-ddac713ae792" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5253dca1-1cc7-4d0a-9149-ddac713ae792")) {
#                     Plotly.newPlot(
#                         '5253dca1-1cc7-4d0a-9149-ddac713ae792',
# ...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# MAPS VISUALIZATION

# %% [markdown]
# IN HOSPITALBEDS DATASET WE HAVE ONLY COUNTRIES BUT I WANT TO CHANGE  INTO LATITUDES AND LONGITUDES

# %%
# !pip install geocoder

# %% [markdown]
# I HAVE INSTALLED GEOCODER BECAUSE I WANT TO CONVERT COUNTRIES OR STATES OR CITIES INTO LATITUDES AND LONGITUDES

# %%
import geocoder
print(geocoder.osm(Hb1.iloc[1,1]).json['lat'])
print(geocoder.osm(Hb1.iloc[1,1]).json['lng'])
# Out:
# 15.9240905
# 80.1863809

# %%
import geocoder
lat =[]
log =[]
for i in range(len(Hb1)):
  lat.append(geocoder.osm(Hb1.iloc[i,1]).json['lat'])
  log.append(geocoder.osm(Hb1.iloc[i,1]).json['lng'])

# %%
Hb1[["Lat"]] = pd.DataFrame(lat)
Hb1[["Log"]] = pd.DataFrame(log)
Hb1.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Sno                   State/UT  ...        Lat        Log
# 0    1  Andaman & Nicobar Islands  ...  10.218834  92.577133
# 1    2             Andhra Pradesh  ...  15.924091  80.186381
# 2    3          Arunachal Pradesh  ...  27.689171  96.459723
# 3    4                      Assam  ...  26.407384  93.255130
# 4    5                      Bihar  ...  25.644085  85.906508
#
# [5 rows x 14 columns]

# %%
px.scatter_geo(Hb1,lat = Hb1.iloc[:,-2],lon = Hb1.iloc[:,-1],color="State/UT",projection="natural earth")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4bbee919-c5e0-46b5-8b1c-b7813cc028eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4bbee919-c5e0-46b5-8b1c-b7813cc028eb")) {
#                     Plotly.newPlot(
#                         '4bbee919-c5e0-46b5-8b1c-b7813cc028eb',
# ...

# %%
### When figure appears just keep mouse on that  you will get a pop up to right upper corner there just click (-) symbol continuosly for 2 to 3 times
fig = px.scatter_mapbox(Hb1,lat = "Lat",lon="Log",color="State/UT",size = "NumDistrictHospitals_HMIS"  ,size_max=30, zoom=3.55,height=700)
fig.update_layout(mapbox_style="open-street-map")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d1e92917-1386-4c8f-b773-da2fbbf8cc4a" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d1e92917-1386-4c8f-b773-da2fbbf8cc4a")) {
#                     Plotly.newPlot(
#                         'd1e92917-1386-4c8f-b773-da2fbbf8cc4a',
# ...

# %%
fig = px.density_mapbox(Hb1,lat = "Lat",lon="Log",height=700,zoom =3.55,animation_frame="NumCommunityHealthCenters_HMIS",radius = 7,hover_name="State/UT")
fig.update_layout(mapbox_style = "open-street-map")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5359cec0-b93c-43e6-a8ea-e899f8148ecc" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5359cec0-b93c-43e6-a8ea-e899f8148ecc")) {
#                     Plotly.newPlot(
#                         '5359cec0-b93c-43e6-a8ea-e899f8148ecc',
# ...
