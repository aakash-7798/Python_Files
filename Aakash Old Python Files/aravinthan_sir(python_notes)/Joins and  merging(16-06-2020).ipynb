# %%
import pandas as pd
pd.set_option("display.max_rows",None)

# %%
week1 = pd.read_csv("pandasfiles/Restaurant - Week 1 Sales.csv")

# %%
week2 = pd.read_csv("pandasfiles/Restaurant - Week 2 Sales.csv")

# %%
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
week2
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
week1.shape
# Out:
# (250, 2)

# %%
week1.ndim
# Out:
# 2

# %%
week2.shape
# Out:
# (250, 2)

# %%
week2.ndim
# Out:
# 2

# %%
pd.merge(week1,week2,on='Customer ID')
# Out:
#     Customer ID  Food ID_x  Food ID_y
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# 5           550          6          7
# 6           101          7          4
# 7            75          6          4
# 8            77          1          7
# 9            77          9          7
# 10           77          2          7
# 11           77          9          7
# 12          628          4          7
# 13          798          9          5
# 14          798          1          5
# 15          462          3          8
# 16          304          3          3
# 17          304          2          3
# 18          189          4          5
# 19          799          8          7
# 20           30          2          4
# 21          249          9          6
# 22          677         10          3
# 23          741          3          8
# ...

# %%
week1.merge(week2,how='inner')
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1.merge(week2,how="left",on="Customer ID",suffixes = ["week1","week2"],indicator=True)
# Out:
#      Customer ID  Food IDweek1  Food IDweek2     _merge
# 0            537             9           5.0       both
# 1             97             4           NaN  left_only
# 2            658             1           NaN  left_only
# 3            202             2           NaN  left_only
# 4            155             9           3.0       both
# 5            213             8           NaN  left_only
# 6            600             1           NaN  left_only
# 7            503             5           8.0       both
# 8            503             5           9.0       both
# 9             71             3           NaN  left_only
# 10           174             3           NaN  left_only
# 11           961             9           NaN  left_only
# 12           966             5           NaN  left_only
# 13           641             4           NaN  left_only
# 14           288             2           NaN  left_only
# 15           149             4           NaN  left_only
# ...

# %%
week1.merge(week2,how="left",on="Food ID",suffixes = ["week1","week2"],indicator=True)
# Out:
#       Customer IDweek1  Food ID  Customer IDweek2 _merge
# 0                  537        9               729   both
# 1                  537        9               732   both
# 2                  537        9               381   both
# 3                  537        9               379   both
# 4                  537        9               574   both
# 5                  537        9               489   both
# 6                  537        9               303   both
# 7                  537        9               548   both
# 8                  537        9               666   both
# 9                  537        9               458   both
# 10                 537        9               653   both
# 11                 537        9               668   both
# 12                 537        9               866   both
# 13                 537        9                55   both
# 14                 537        9               936   both
# ...

# %% [markdown]
# # CONCATINATION AND APPEND

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
modified = pd.concat([week1,week2],keys=['week1','week2'],ignore_index=True)

# %%
modified
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# 30           419        7
# 31            20        1
# 32           822        6
# 33           226       10
# ...

# %%
week1.append(week1,ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# 30           419        7
# 31            20        1
# 32           822        6
# 33           226       10
# ...
