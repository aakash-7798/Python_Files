# %%
import tensorflow as ts

# %%
import tensorflow.keras

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv("Car_Purchasing_Data.csv",encoding="ISO-8859-1")
df = pd.read_csv("Car_Purchasing_Data.csv")

# %%
df
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           Country  Gender        Age  Annual Salary  Credit Card Debt  \
# ...

# %%
df.columns
# Out:
# Index(['Customer Name', 'Customer e-mail', 'Country', 'Gender', 'Age',
#        'Annual Salary', 'Credit Card Debt', 'Net Worth',
#        'Car Purchase Amount'],
#       dtype='object')

# %%
X = df[['Gender', 'Age',
       'Annual Salary', 'Credit Card Debt', 'Net Worth']]

# %%
y = df["Car Purchase Amount"]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_scaled = MinMaxScaler().fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.        , 0.4370344 , 0.53515116, 0.57836085, 0.22342985],
#        [0.        , 0.41741247, 0.58308616, 0.476028  , 0.52140195],
#        [1.        , 0.46305795, 0.42248189, 0.55579674, 0.63108896],
#        ...,
#        [1.        , 0.67886994, 0.61110973, 0.52822145, 0.75972584],
#        [1.        , 0.78321017, 0.37264988, 0.69914746, 0.3243129 ],
#        [1.        , 0.53462305, 0.51713347, 0.46690159, 0.45198622]])

# %%
y = y.values.reshape(-1,1)

# %%
y
# Out:
# array([[35321.45877],
#        [45115.52566],
#        [42925.70921],
#        [67422.36313],
#        [55915.46248],
#        [56611.99784],
#        [28925.70549],
#        [47434.98265],
#        [48013.6141 ],
#        [38189.50601],
#        [59045.51309],
#        [42288.81046],
#        [28700.0334 ],
#        [49258.87571],
#        [49510.03356],
#        [53017.26723],
#        [41814.72067],
#        [43901.71244],
#        [44633.99241],
#        [54827.52403],
#        [51130.95379],
#        [43402.31525],
#        [47240.86004],
#        [46635.49432],
#        [45078.40193],
#        [44387.58412],
#        [37161.55393],
#        [49091.97185],
#        [58350.31809],
#        [43994.35972],
#        [17584.56963],
#        [44650.36073],
#        [66363.89316],
#        [53489.46214],
#        [39810.34817],
#        [51612.14311],
#        [38978.67458],
#        [10092.22509],
#        [35928.52404],
#        [54823.19221],
#        [45805.67186],
# ...

# %%
y_scaled = MinMaxScaler().fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.37072477],
#        [0.50866938],
#        [0.47782689],
#        [0.82285018],
#        [0.66078116],
#        [0.67059152],
#        [0.28064374],
#        [0.54133778],
#        [0.54948752],
#        [0.4111198 ],
#        [0.70486638],
#        [0.46885649],
#        [0.27746526],
#        [0.56702642],
#        [0.57056385],
#        [0.61996151],
#        [0.46217916],
#        [0.49157341],
#        [0.50188722],
#        [0.64545808],
#        [0.59339372],
#        [0.48453965],
#        [0.53860366],
#        [0.53007738],
#        [0.50814651],
#        [0.49841668],
#        [0.3966416 ],
#        [0.56467566],
#        [0.6950749 ],
#        [0.49287831],
#        [0.12090943],
#        [0.50211776],
#        [0.80794216],
#        [0.62661214],
#        [0.43394857],
#        [0.60017103],
#        [0.42223485],
#        [0.01538345],
#        [0.37927499],
#        [0.64539707],
#        [0.51838974],
#        [0.45869677],
#        [0.26804521],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y_scaled)

# %%
x_train.shape
# Out:
# (375, 5)

# %%
x_test.shape
# Out:
# (125, 5)

# %%
import tensorflow.keras

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense

# %%
model = Sequential()

# %%
### Input Layer
model.add(Dense(30,input_dim = 5,activation = 'relu'))

# %%
### Hidden Layer
model.add(Dense(30,activation= 'relu'))

# %%
### Final Layer
model.add(Dense(1,activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 25)                150
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 26
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                60
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                1550
# _________________________________________________________________
# dense_5 (Dense)              (None, 40)                2040
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 41
# ...

# %%
model.compile(optimizer='adam',loss = "mean_squared_error")

# %%
epochs_hist = model.fit(x_train,y_train,epochs=30,batch_size=50,verbose=1,validation_split=0.3)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2895 - val_loss: 0.2622
# Epoch 2/30
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2438 - val_loss: 0.2351
# Epoch 3/30
# 6/6 [==============================] - ETA: 0s - loss: 0.232 - 0s 15ms/step - loss: 0.2125 - val_loss: 0.2006
# Epoch 4/30
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1753 - val_loss: 0.1533
# Epoch 5/30
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1221 - val_loss: 0.0800
# Epoch 6/30
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0455 - val_loss: 0.0072
# Epoch 7/30
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0126 - val_loss: 0.0255
# Epoch 8/30
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0165 - val_loss: 0.0053
# Epoch 9/30
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0106
# Epoch 10/30
# ...

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([[0.28733426],
#        [0.40037784],
#        [0.23577386],
#        [0.41326225],
#        [0.3682778 ],
#        [0.39574656],
#        [0.6677673 ],
#        [0.40003383],
#        [0.61528   ],
#        [0.34952897],
#        [0.26568773],
#        [0.48402736],
#        [0.66632897],
#        [0.19464503],
#        [0.79971987],
#        [0.2003872 ],
#        [0.8497613 ],
#        [0.23109744],
#        [0.49273968],
#        [0.61084145],
#        [0.31564927],
#        [0.62693715],
#        [0.4167827 ],
#        [0.33589453],
#        [0.43231317],
#        [0.5516524 ],
#        [0.3099217 ],
#        [0.83724076],
#        [0.42046955],
#        [0.4543766 ],
#        [0.42476144],
#        [0.71761984],
#        [0.3419813 ],
#        [0.31704757],
#        [0.547265  ],
#        [0.3782165 ],
#        [0.42225483],
#        [0.4143473 ],
#        [0.8202264 ],
#        [0.45819137],
#        [0.5884917 ],
#        [0.25247782],
#        [0.3090748 ],
# ...

# %%
from IPython.display import IFrame

# %%
IFrame("https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.33708&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false"
       ,height=500,width=900)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.33708&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
