# %%
import pdftables_api

c = pdftables_api.Client('888ja8qtoa7e')
c.xlsx('C:\\Users\\aakas\\Documents\\My Kindle Content\\Input Tax Credit.pdf',"ITC1")

# %%
import pandas as pd

# %%
pd.read_excel("ITC1.xlsx")
# Out:
#                                               CHAPTER  \
# 0                                    INPUT TAX CREDIT
# 1   For the sake of brevity, input tax credit has ...
# 2   The section numbers referred to in the Chapter...
# 3                                          specified.
# 4                                                 NaN
# 5   After studying this Chapter, you will be able to:
# 6                                                   
# 7                                                 NaN
# 8                                                   
# 9                                                 NaN
# 10                                                NaN
# 11                                                  
# 12                                                NaN
# 13                                                  
# 14                                                NaN
# 15                                                NaN
# ...
