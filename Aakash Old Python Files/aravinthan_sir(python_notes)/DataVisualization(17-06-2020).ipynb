# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
### Boxplot
sns.boxplot(x="Species",y="SepalLengthCm",data=df)

# %%
## Violin Plot
sns.violinplot(x="Species",y="SepalLengthCm",data=df)

# %%
sns.pairplot(df)

# %%
df = pd.read_csv("tips.csv")

# %%
df
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  244 non-null    int64
#  1   total_bill  244 non-null    float64
#  2   tip         244 non-null    float64
#  3   sex         244 non-null    object
#  4   smoker      244 non-null    object
#  5   day         244 non-null    object
#  6   time        244 non-null    object
#  7   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %%
sns.boxplot(x = "smoker",y = "tip",data=df)

# %%
sns.boxplot(x = "time",y = "tip",data=df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
sns.boxplot(x = "day",y = "tip",hue='smoker',data=df)

# %%
sns.boxplot(x = "smoker",y = "tip",hue='time',data=df)

# %%
sns.boxplot(x = "time",y = "tip",data=df,order=["Dinner","Lunch"])

# %%
sns.boxplot(x = "time",y = "tip",data=df,order=["Dinner","Lunch"],palette='Set1')

# %%
##Swarm plot
sns.swarmplot(x = "time",y = "tip",data=df,color="blue")
sns.boxplot(x = "day",y = "tip",data=df)

# %%
sns.boxplot(x='day',y='tip',data=df,order=['Sun', 'Sat'])
sns.swarmplot(x='day',y='tip',data=df,order=['Sun', 'Sat'],color='red')

# %%
#Scatter plot
df = pd.read_csv('Iris.csv')

df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Scatter plot
sns.scatterplot(x = 'SepalLengthCm',y = 'SepalWidthCm',data=df)

# %%
sns.scatterplot(x = 'PetalLengthCm',y = 'PetalWidthCm',hue='Species',data=df)

# %%
## Bar graph
df = pd.read_csv('tips.csv')
sns.barplot(x = 'day',y='total_bill',data=df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
sns.barplot(x = 'smoker',y='tip',data=df)

# %%
sns.barplot(x = 'smoker',y='tip',hue='day',data=df)

# %%
from matplotlib import pyplot as plt
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4)
fig.set_size_inches(10,5)
sns.barplot(x = 'smoker',y='tip',data=df,ax=ax1)
sns.barplot(x = 'smoker',y='tip',hue='day',data=df,ax=ax2)
sns.barplot(x = 'smoker',y='tip',data=df,ax=ax3)
sns.barplot(x = 'smoker',y='tip',hue='day',data=df,ax=ax4)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  244 non-null    int64
#  1   total_bill  244 non-null    float64
#  2   tip         244 non-null    float64
#  3   sex         244 non-null    object
#  4   smoker      244 non-null    object
#  5   day         244 non-null    object
#  6   time        244 non-null    object
#  7   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %%
df_intf = ["total_bill","tip","size"]
df_obj  = ["sex","smoker","day","time"]

# %%
fig,axes = plt.subplots(nrows=4,ncols=3) 
fig.set_size_inches(20, 20)
sns.boxplot(x = df_obj[0],y= df_intf[0],data=df,ax=axes[0,0])    
sns.boxplot(x = df_obj[0],y= df_intf[1],data=df,ax=axes[0,1])    
sns.boxplot(x = df_obj[0],y= df_intf[2],data=df,ax=axes[0,2])     
sns.boxplot(x = df_obj[1],y= df_intf[0],data=df,ax=axes[1,0])    
sns.boxplot(x = df_obj[1],y= df_intf[1],data=df,ax=axes[1,1])    
sns.boxplot(x = df_obj[1],y= df_intf[2],data=df,ax=axes[1,2]) 
sns.boxplot(x = df_obj[2],y= df_intf[0],data=df,ax=axes[2,0])     
sns.boxplot(x = df_obj[2],y= df_intf[1],data=df,ax=axes[2,1])     
sns.boxplot(x = df_obj[2],y= df_intf[2],data=df,ax=axes[2,2]) 
sns.boxplot(x = df_obj[3],y= df_intf[0],data=df,ax=axes[3,0])    
sns.boxplot(x = df_obj[3],y= df_intf[1],data=df,ax=axes[3,1])    
sns.boxplot(x = df_obj[3],y= df_intf[2],data=df,ax=axes[3,2])

# %%
fig,axes = plt.subplots(nrows=4,ncols=3) 
fig.set_size_inches(20, 20)
for i in range(len(df_obj)):
        for j in range(len(df_intf)):
               sns.boxplot(x = df_obj[i],y= df_intf[j],data=df,ax=axes[i,j])

# %%
import seaborn as sns
fig,axes = plt.subplots(nrows=4,ncols=3) 
fig.set_size_inches(20, 20)
for i in range(len(df_obj)):
        for j in range(len(df_intf)):
            sns.boxplot(x = df_obj[i],y= df_intf[j],data=df,ax = axes[i,j])

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(11)
y = np.random.rand(len(x), 9)*10

fig, axes = plt.subplots(3,3, sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    ax.bar(x, y[:,i], color=plt.cm.Paired(i/10.))

plt.show()

# %%
enumerate(axes.flatten())
