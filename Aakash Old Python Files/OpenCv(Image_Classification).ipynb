# %%
from PIL import Image

# %%
image1 = Image.open("beachphoto.jpg")
image2 = Image.open("beachphoto.jpg").convert("L")

# %%
image1.resize((128,128))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2870360D108>

# %%
image1.crop((100,100,400,400))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x28704A87D48>

# %%
image1.crop((100,100,400,400)).transpose(Image.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x28702F30448>

# %%
image1.rotate(360)
# Out:
# <PIL.Image.Image image mode=RGB size=750x562 at 0x28705048E48>

# %%
from pylab import *

# %%
image = array(Image.open("beachphoto.jpg"))

# %%
imshow(image)

# %%
x = [100,100,400,400]
y = [200,500,200,500]
plot(x,y,'r*')

# %%
plot(x[:2],y[:2])
