# %%
import re
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from getpass import getpass
import urllib
import urllib.request
import requests
options = Options()
options.add_argument("start-maximized")
from IPython.display import display, HTML    #,Image
import time
from PIL import Image
from io import BytesIO
from bs4 import BeautifulSoup
import json

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\aakas\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\aakas\AppData\Local\Temp/ipykernel_1216/1503906442.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://www.instagram.com/accounts/login/')
# Search = input("Enter username you want to search  : ")
# driver.get(f'https://www.instagram.com/{Search}/')

# %%
driver.find_element(By.XPATH,'//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys('aakash__7798')
time.sleep(0.5)
driver.find_element(By.XPATH,'//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys(getpass("Enter Password"))
time.sleep(0.5)
driver.find_element(By.XPATH,'//*[@id="loginForm"]/div/div[3]/button/div').click()
time.sleep(0.5)
# Out:
# Enter Password········

# %%
# driver.find_element(By.XPATH,'//*[@id="react-root"]/div/div/section/main/div/div/div/div/button').click()
# time.sleep(0.5)
driver.find_element(By.XPATH,'//*[@id="mount_0_0_8B"]/div/div[1]/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div/div/div/div[3]/button[2]').click()
time.sleep(0.5)

# %%
# driver.find_element(By.XPATH,'//*[@id="mount_0_0_Rk"]/div/div[1]/div/div[1]/div/div/div[1]/div[1]/section/nav/div[2]/div/div/div[2]/input').send_keys(Keys.CLEAR)
# time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1216/3215276359.py in <module>
# ----> 1 driver.find_element(By.XPATH,'//*[@id="mount_0_0_RK"]/div/div[1]/div/div[1]/div/div/div[1]/div[1]/section/nav/div[2]/div/div/div[2]/input').send_keys(Keys.CLEAR)
#       2 time.sleep(1)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1249             value = '[name="%s"]' % value
#    1250
# -> 1251         return self.execute(Command.FIND_ELEMENT, {
#    1252             'using': by,
#    1253             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# ...

# %%
# driver.find_element(By.XPATH,'//*[@id="mount_0_0_8B"]/div/div[1]/div/div[1]/div/div/div[1]/div[1]/section/nav/div[2]/div/div/div[2]/input').clear()
# time.sleep(1)
driver.find_element(By.XPATH,'//*[@id="mount_0_0_8B"]/div/div[1]/div/div[1]/div/div/div[1]/div[1]/section/nav/div[2]/div/div/div[2]/input').send_keys(input(" Search Here (Enter UserName ) : "))
time.sleep(2)
driver.find_element(By.CSS_SELECTOR,'div._abnx a').click()
# driver.find_element(By.CSS_SELECTOR,'div._aa-i a').click()
# Out:
#  Search Here (Enter UserName ) : urstrulymahesh

# %%
Images = [i.get_attribute('src') for i in driver.find_elements(By.TAG_NAME,'img') ]
print("Total Images Found : ",len(Images))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1216/729938275.py in <module>
# ----> 1 Images = [i.get_attribute('src') for i in driver.find_elements(By.TAG_NAME,'img') ]
#       2 print("Total Images Found : ",len(Images))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1282         # Return empty list if driver returns null
#    1283         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1284         return self.execute(Command.FIND_ELEMENTS, {
#    1285             'using': by,
#    1286             'value': value})['value'] or []
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     426
#     427         params = self._wrap_value(params)
# ...

# %%
Image.open(BytesIO(urllib.request.urlopen(Images[38]).read()))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x12DA3FD5970>
